# %% [markdown]
# # Download list of companies that are related to biotechnology
# ---

# %%
import pandas as pd

# %%
pd.read_csv("../results/02d-merge_exceptions_2nd_pass/biotech_company_info_complete_07_09_2021.csv")
# Out:
#                       name_orig                                url_orig  \
# 0                     4d Pharma          https://www.4dpharmaplc.com/en
# 1               ACRO Biosystems         https://www.acrobiosystems.com/
# 2              ADC Therapeutics        https://www.adctherapeutics.com/
# 3    AKL Research & Development                      https://aklrd.com/
# 4             AMS Biotechnology                 https://www.amsbio.com/
# ..                          ...                                     ...
# 645                      Sareum                  http://www.sareum.com/
# 646         Sekisui Diagnostics  https://www.bioproduction-sekisui.com/
# 647                Small Pharma          https://www.smallpharma.co.uk/
# 648                   Synbiosis              https://www.synbiosis.com/
# 649                       Ziath                      https://ziath.com/
#
#     location_orig                                          desc_orig  \
# ...

# %%
pd.read_csv("../results/02b-merge_tidy_company_info/biotech_company_info_exceptions_07_09_2021.csv")
# Out:
#                    name_orig  \
# 0                 AMO Pharma
# 1         Cerus Endovascular
# 2     Chargepoint Technology
# 3          Clinical Metadata
# 4                   CryoLife
# 5                     Cytiva
# 6           DestiNA Genomics
# 7                  Enara Bio
# 8            GlaxoSmithKline
# 9                 Inotec AMD
# 10               Kite Pharma
# 11                     Lidco
# 12       Mestag Therapeutics
# 13              MicroVention
# 14         Microsaic Systems
# 15          Modulus Oncology
# 16        Nanna Therapeutics
# 17            Nemaura Pharma
# 18               OKYO Pharma
# 19  Oxford Brain Diagnostics
# 20                 Pharmidex
# 21                Plasticell
# 22                 Pneumagen
# 23                 Recipharm
# 24               Redx Pharma
# 25                 ReproCELL
# 26                    Sareum
# 27       Sekisui Diagnostics
# 28              Small Pharma
# 29                 Synbiosis
# 30                     Ziath
#
# ...
